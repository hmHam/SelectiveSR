# %%
# !python train_agent.py --channel 1 --weight 0.00 --outdir ./v2 --start 0 --end 1 --gpu 0
# Out:
# start trainning...
# iteration:  500
# iteration:  1000
# iteration:  1500
# iteration:  2000
# ^C
# Traceback (most recent call last):
#   File "train_agent.py", line 232, in <module>
#     train(channel=args.channel, weight=args.weight, outdir=args.outdir, gpu=args.gpu, seed=seed)
#   File "train_agent.py", line 174, in train
#     s, r, history = step(Qnet, s, history, filt, channel, gamma=gamma, eps=eps, device=device)
#   File "train_agent.py", line 85, in step
#     _, q = Qnet(x.to(device))
# KeyboardInterrupt

# %%
import pickle

# %%
from matplotlib import pyplot as plt
import numpy as np

with open('v2channel01_weight000_seed00/reward.pkl', 'rb') as f:
    reward = pickle.load(f)
n = 1000
ret = np.cumsum(reward)
ret[n:] = ret[n:] - ret[:-n]
r = ret[n-1:] / n

plt.plot(r)
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

with open('channel01_weight000_seed00/reward.pkl', 'rb') as f:
    reward = pickle.load(f)
n = 1000
ret = np.cumsum(reward)
ret[n:] = ret[n:] - ret[:-n]
r = ret[n-1:] / n

plt.plot(r)
plt.show()

# %%
a = np.arange(10)
np.cumsum(a)
# Out:
# array([ 0,  1,  3,  6, 10, 15, 21, 28, 36, 45])

# %%
plt.plot()
plt.show()

# %%
[m for m in dir(np) if 'sum' in m]
# Out:
# ['cumsum', 'einsum', 'einsum_path', 'nancumsum', 'nansum', 'sum']
